# %% [markdown]
# # Using the basicrobot
# See the project it.unibo.basicrobot2020

# %% [markdown]
# ## Interaction with the basicrobot qactor
# See the model: <a href="../src/basicrobot.qak" target="code">basicrobot.qak</a>.
# <ol>
#     <li>
#         Activate the virtual robot and oper a browser on <tt>localhost:8090</tt>
#     </li>
#     <li>Launch the <tt>basicrobot</tt> as a 'standalone' application (microservice)
# <pre>
# cd C:\..\it.unibo.basicrobot2020-1.0\bin
# it.unibo.basicrobot2020.bat
# </pre>
#     </li>
#     <li>
#         Execute the python code hereunder to move the robot
#     </li>
#     <li>
#         Look at the received data when the (virtual) robot hits an obstacle
#     </li>
# </ol>

# %%
##############################################################
# sendDispatch       : sends a command in output
# read               : acquires data from input
##############################################################
import socket
import time

robotName      = "basicrobot" # robotadapter | basicrobot

hostAdress     = '192.168.43.171'
basicRobotPort = 8018     
 

goForwardMsg  = "msg(cmd,dispatch,python,"+ robotName +",cmd(w),1)"
goBackwardMsg = "msg(cmd,dispatch,python,"+ robotName +",cmd(s),1)" 
turnLeftMsg   = "msg(cmd,dispatch,python,"+ robotName +",cmd(a),1)"  
turnRightMsg  = "msg(cmd,dispatch,python,"+ robotName +",cmd(d),1)"  
haltMsg       = "msg(cmd,dispatch,python,"+ robotName +",cmd(h),1)"
alermEvent    = "msg(alarm,event,python,none,alarm(intruder),1)"

sock          = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

def connect(port) :
    server_address = (hostAdress, port)
    sock.connect(server_address)    
    print("CONNECTED WITH ", server_address )

def send( message ) :
    msg = message + "\n"
    byt=msg.encode()    #required in Python3
    sock.send(byt)

def terminate() :
    read(1) 
    sock.close()    #qak infrastr receives a msg null
    print("BYE")

def read(timeout) :
    sock.settimeout(timeout)
    recStr = ""
    try:
        while( not recStr.endswith("\n") ) :          
            recBytes = sock.recv(1024) # try to receive 1024 bytes
            recStr   = recStr + recBytes.decode('utf8')           
            #print("RECEIVED partial:" , recStr )
        print("RECEIVED:" , recStr )
    except socket.timeout: # fail after 1 second of no activity
        print("no data back ")

def console() :  
    cmd = str(input()) 
    while( cmd != "z" ) :
        if( cmd == "w" ) :
            send( goForwardMsg ) 
        if( cmd == "s" ) :
            send( goBackwardMsg ) 
        if( cmd == "a" ) :
            send( turnLeftMsg ) 
        if( cmd == "d" ) :
            send( turnRightMsg ) 
        if( cmd == "h" ) :
            send( haltMsg ) 
        if( cmd == "m" ) :
            send( alermEvent ) 
        read(1)  
        cmd = str(input())
##################################################
connect(basicRobotPort)
console()
terminate()
# Out:
# CONNECTED WITH  ('192.168.43.171', 8018)
# w
# RECEIVED: msg(polar,event,forradar,none,polar(321,0),332)
#
# qh
# RECEIVED: msg(polar,event,forradar,none,polar(318,0),338)
# msg(polar,event,forradar,none,polar(400,0),344)
# msg(polar,event,forradar,none,polar(187,0),353)
# msg(polar,event,forradar,none,polar(400,0),357)
# msg(polar,event,forradar,none,polar(184,0),362)
# msg(polar,event,forradar,none,polar(400,0),366)
# msg(polar,event,forradar,none,polar(182,0),370)
# msg(polar,event,forradar,none,polar(180,0),376)
# msg(polar,event,forradar,none,polar(177,0),382)
# msg(polar,event,forradar,none,polar(175,0),391)
# msg(polar,event,forradar,none,polar(173,0),397)
# msg(polar,event,forradar,none,polar(171,0),405)
# msg(polar,event,forradar,none,polar(169,0),410)
# msg(polar,event,forradar,none,polar(167,0),419)
# msg(polar,event,forradar,none,polar(165,0),426)
# msg(polar,event,forradar,none,polar(163,0),432)
# msg(polar,event,forradar,none,polar(161,0),439)
# msg(polar,event,forradar,none,polar(159,0),447)
# msg(polar,event,forradar,none,polar(157,0),454)
# msg(polar,event,forradar,none,polar(155,0),462)
# msg(polar,event,forradar,none,polar(153,0),468)
# msg(polar,event,forradar,none,polar(151,0),475)
# msg(polar,event,forradar,none,polar(149,0),483)
# msg(polar,event,forradar,none,polar(147,0),490)
# msg(polar,event,forradar,none,polar(145,0),497)
# msg(polar,event,forradar,none,polar(143,0),505)
# msg(polar,event,forradar,none,polar(141,0),512)
# msg(polar,event,forradar,none,polar(139,0),520)
# msg(polar,event,forradar,none,polar(137,0),526)
# msg(polar,event,forradar,none,polar(135,0),534)
# msg(polar,event,forradar,none,polar(133,0),542)
# msg(polar,event,forradar,none,polar(131,0),549)
# msg(polar,event,forradar,none,polar(129,0),557)
# msg(polar,event,forradar,none,polar(127,0),565)
# msg(polar,event,forradar,none,polar(125,0),572)
# msg(polar,event,forradar,none,polar(123,0),581)
# msg(polar,event,forradar,none,polar(121,0),588)
